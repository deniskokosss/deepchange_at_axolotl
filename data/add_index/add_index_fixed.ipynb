# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
rupaths = list(Path('/home/nikolare/_projects/axolotl/axolotl24_shared_task').glob('data/*/*test.ru.tsv'))
print(rupaths)
p = next(iter(rupaths))
print(p)
# Out:
# [PosixPath('/home/nikolare/_projects/axolotl/axolotl24_shared_task/data/test/axolotl.test.ru.tsv')]
# /home/nikolare/_projects/axolotl/axolotl24_shared_task/data/test/axolotl.test.ru.tsv

# %%
df = pd.read_csv(p, sep='\t')
df.example = df.example.str.strip()  # Some examples contain space as the last symbol, which make further merging incorrect
print(len(df), df.word.nunique(), df.example.nunique())
df.head()
# Out:
# 2126 211 1990
#     usage_id     word     orth             sense_id  \
# 0  test_ru_0  мёрзлый  мёрзлый  merzlyj_khrrgztit4U
# 1  test_ru_1  мёрзлый  мёрзлый                  NaN
# 2  test_ru_2  мёрзлый  мёрзлый                  NaN
# 3  test_ru_3  мёрзлый  мёрзлый                  NaN
# 4  test_ru_4  мёрзлый  мёрзлый                  NaN
#
#                                    gloss  \
# 0  разг., устар. очень холодный; ледяной
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                              example  indices_target_token  \
# 0  Мерзлая земля скажется, только руку приложи От...                   NaN
# 1  Пантелей Прокофьевич сунул Григорию мёрзлую ру...                   NaN
# 2  Между домом и рельсами, за широкой мёрзлой луж...                   NaN
# 3  — Да, холодно, должно быть. На полу мёрзлые та...                   NaN
# 4  Когда мосты были прорваны, безоружные солдаты,...                   NaN
#
#   date period
# 0  old    old
# 1  new    new
# 2  new    new
# 3  new    new
# 4  new    new

# %% [markdown]
# # Generate wordforms for each lemma with Pymorphy2

# %%
df.word.drop_duplicates().to_csv('lemmas.tsv', sep='\t', index=False, header=None)
# !wc lemmas.tsv
# Out:
#  211  211 2857 lemmas.tsv

# %%
SUMMERWSI_HOME='/home/nikolare/_projects/summer-wsi/retrieval_lscd/summer-wsi'

# %%
# !python $SUMMERWSI_HOME/retrieval/modules/generate_forms_pymorphy.py lemmas.tsv forms.tsv
# !cut -f 1 -d '_' forms.tsv|sort|uniq|wc
# Out:
#     211     211    2857

# %% [markdown]
# ## Add additional wordforms present in the dataset

# %%
lemma2addforms = {}
with open('forms_add.tsv','r') as inp:
    for l in inp:
        ff = l.strip().split('\t')
        lemma2addforms[ff[0]] = ff[1:]

# %%
with open('forms.tsv','r') as inp, open('forms_final.tsv','w') as outp:
    for l in inp:
        ff = l.strip().split('\t')
        lemma = ff[0].split('_')[0]
        if lemma in lemma2addforms:                    
            ff.extend(lemma2addforms[lemma])
        print('\t'.join(ff), file=outp)

# %%
# !diff forms.tsv forms_final.tsv
# Out:
# 101c101
# < шаманить_INFN	шаманив	шаманившему	шаманишь	шаманим	шаманившею	шаманите	шаманящей	шаманящим	шаманившей	шаманившим	шаманила	шаманит	шаманило	шамань	шаманя	шаманю	шаманил	шаманящую	шаманивши	шаманящему	шаманить	шаманившую	шаманящие	шаманившими	шаманившие	шаманящих	шаманившее	шаманящею	шаманящее	шаманящий	шаманившая	шаманьте	шаманящими	шаманят	шаманили	шаманящего	шаманящем	шаманивший	шаманящая	шаманившего	шаманившем	шаманивших
# ---
# > шаманить_INFN	шаманив	шаманившему	шаманишь	шаманим	шаманившею	шаманите	шаманящей	шаманящим	шаманившей	шаманившим	шаманила	шаманит	шаманило	шамань	шаманя	шаманю	шаманил	шаманящую	шаманивши	шаманящему	шаманить	шаманившую	шаманящие	шаманившими	шаманившие	шаманящих	шаманившее	шаманящею	шаманящее	шаманящий	шаманившая	шаманьте	шаманящими	шаманят	шаманили	шаманящего	шаманящем	шаманивший	шаманящая	шаманившего	шаманившем	шаманивших	шаманем
# 191c191
# < кадра_	кадра
# ---
# > кадра_	кадра	кадрой	кадры
# 214c214
# < хлебало_	хлебало
# ---
# > хлебало_	хлебало	хлебала

# %% [markdown]
# # Find usages of the generated wordforms

# %%
assert df.example.str.contains('\n').sum()==0, 'examples contain newlines, cannot write as plain text'
with open('corpus.txt', 'w') as outp:
    for ex in df.example.dropna():
        print(ex, file=outp)
# !head corpus.txt
# Out:
# Мерзлая земля скажется, только руку приложи От того нельзя, что земля мерзла. Мерзлой
# Пантелей Прокофьевич сунул Григорию мёрзлую руку, сел на край лавки, запахивая полу тулупа, обходя взглядом Аксинью, пристывшую у люльки.
# Между домом и рельсами, за широкой мёрзлой лужей, проходила дорога, по которой возили дрова и воду.
# — Да, холодно, должно быть. На полу мёрзлые тараканы валяются. И мыши тоже помёрзли.
# Когда мосты были прорваны, безоружные солдаты, московские жители, женщины с детьми, бывшие в обозе французов, — всё под влиянием силы инерции не сдавалось, а бежало вперед в лодки, в мёрзлую воду.
# Мёрзлый пар валил с загнанных насмерть лошадей, с бегущих людей.
# Я подошёл к окну, приложил лоб к мёрзлому стеклу и помню, что мне лоб обожгло льдом, как огнём.
# Неужели и в уголку мёрзлой хижины не хочешь ты дать бедняку местечка?
# Все больны, все бредят, кто хохочет, кто на стену лезет; в избах смрад, ни воды подать, ни принести её некому, а пищей служит один мёрзлый картофель.
# Винтом крутится снег в мёрзлом воздухе и ложится косыми полосами поперёк погоста…

# %%
# !python $SUMMERWSI_HOME/retrieval/modules/regex_retriever.py forms_final.tsv corpus.txt usages
# Out:
# Compiled regexp (maybe shortened):
#  re.compile('\\b(померзлее|мерзло|мёрзлого|мерзл|мёрзлых|мерзлая|помёрзлей|мёрзлою|мёрзлой|мерзлое|мерзла|мерзлый|мёрзлыми|мёрзлая|мёрзлому|мёрзлые|мёрзло|мерзлого|мёрзлый|мерзлой|мёрзлее|мерзлую|мёрзлым|мерзлее|, re.IGNORECASE)
#
# Full regexp:
#  \b(померзлее|мерзло|мёрзлого|мерзл|мёрзлых|мерзлая|помёрзлей|мёрзлою|мёрзлой|мерзлое|мерзла|мерзлый|мёрзлыми|мёрзлая|мёрзлому|мёрзлые|мёрзло|мерзлого|мёрзлый|мерзлой|мёрзлее|мерзлую|мёрзлым|мерзлее|мерзлою|мерзлей|мерзлым|мерзлых|мёрзлую|мёрзла|мерзлом|мерзлому|мёрзлом|мерзлы|мерзлыми|померзлей|мерзлые|мёрзлы|мёрзлей|помёрзлее|мёрзлое|мёрзл|элемент|элементы|элемента|элементу|элементом|элементам|элементами|элементах|элементе|элементов|кабаках|кабаки|кабаками|кабаков|кабак|кабаке|кабаку|кабака|кабакам|кабаком|трубаче|трубачей|трубач|трубачи|трубачу|трубача|трубачом|трубачам|трубачами|трубачах|славнейшей|славнейшими|славное|пославнее|славнее|славнейшего|славную|славными|славна|славней|славен|славны|славным|славном|славной|славного|славнейшее|славных|славный|славнейшим|славному|славнейшая|славные|славнейшем|славнейшую|славнейших|славнейший|пославней|славнейшие|славною|славно|славнейшему|славная|славнейшею|центрами|центр|центрам|центров|центре|центра|центрах|центром|центры|центру|установке|установка|установках|установок|установку|установками|установкам|установкою|установкой|установки|символе|символов|символ|символа|символы|символом|символу|символами|символах|символам|мелькавшим|мелькавший|мелькавшие|мелькающему|мелькающее|мелькавшую|мелькать|мелькающий|мелькавших|мелькавши|мелькавшему|мелькающая|мелькая|мелькаете|мелькайте|мелькающую|мелькающею|мелькали|мелькав|мелькала|мелькающего|мелькающих|мелькавшего|мелькавшая|мелькающим|мелькай|мелькающими|мелькаешь|мелькаем|мелькавшем|мелькающем|мелькавшее|мелькал|мелькавшей|мелькают|мелькавшими|мелькает|мелькавшею|мелькало|мелькаю|мелькающей|мелькающие|ладом|ладе|лада|лад|ладах|лады|ладов|ладу|ладам|ладами|судаком|судаков|судаки|судакам|судака|судак|судаку|судаке|судаками|судаках|косарями|косарём|косарю|косарем|косаря|косарям|косаре|косарь|косари|косарях|косарей|жалкая|жалкий|пожалче|жалчайшую|наижалчайший|жалчайшая|жалко|жалкого|жалчайшим|жалчайшею|наижалчайшею|наижалчайшие|наижалчайшее|наижалчайшая|жалчайшем|жалчайших|наижалчайшему|жалком|пожалчей|жалчайшей|жалчайшими|жалчайший|наижалчайших|наижалчайшим|наижалчайшими|жалкими|жалчайшего|жалкое|жалким|жалкую|жалчайшему|жалкою|жалка|наижалчайшем|жалче|жалких|жалкой|жалкому|жалчей|наижалчайшей|наижалчайшего|жалки|наижалчайшую|жалчайшее|жалчайшие|жалок|жалкие|кисой|кисах|кисы|киса|кису|кисе|кисам|кис|кисами|кисою|сидячею|сидячей|сидячие|сидячую|сидячим|сидячи|сидячих|сидяч|сидяча|сидячем|сидячему|сидячего|сидячая|сидячее|сидячими|посидячее|сидяче|сидячий|посидячей|магиях|магий|магиям|магии|магией|магия|магиею|магиями|магию|скорости|скоростью|скоростями|скоростям|скоростей|скорость|скоростях|шлифовальны|шлифовальный|шлифовально|шлифовальные|шлифовальная|шлифовальное|шлифовального|шлифовальна|шлифовальней|шлифовальной|шлифовален|шлифовальнее|шлифовальных|пошлифовальней|шлифовальным|пошлифовальнее|шлифовальными|шлифовальною|шлифовальному|шлифовальную|шлифовальном|мебельного|мебельней|мебельнее|мебельными|мебельных|мебельною|мебельный|мебельны|мебельна|мебельной|помебельней|мебельная|мебельно|мебельном|мебельным|мебельному|помебельнее|мебельное|мебельную|мебелен|мебельные|чеки|чеках|чеке|чекой|чеку|чекою|чека|чек|чекам|чеками|чадов|чада|чадах|чад|чадами|чадам|чады|чаду|чаде|чадом|скатках|скаткой|скаток|скатки|скатке|скаткам|скаткою|скатками|скатку|скатка|кровле|кровлей|кровлями|кровлях|кровлею|кровли|кровлю|кровлям|кровель|кровля|тараннее|таранную|потараннее|таранных|таранна|таранны|потаранней|таранною|таранная|таранном|таранное|таранными|таранней|таранному|таранным|таранно|таранный|таранен|таранные|таранного|таранной|мёде|меде|мед|мёдом|мёд|меды|медам|медов|медами|медом|меду|медах|мёда|меда|мёду|маячили|маячившую|маячащею|маячивших|маячащих|маячившему|маячившее|маячьте|маячат|маячившей|маячащем|маячившие|маячащего|маячил|маячить|маячит|маячившими|маячь|маячащий|маячившем|маячив|маячу|маячишь|маячившею|маячите|маячила|маячим|маячащая|маяча|маячащими|маячащую|маячивши|маячащему|маячивший|маячившая|маячащим|маячащее|маячило|маячащей|маячившим|маячи ...
#
# Retrieving usages...
# 100%|███████████████████████████████| 478086/478086 [00:04<00:00, 101136.74it/s]
# Converting retrieved usages to a DataFrame...
#
# Usages found:
# другой_ADJF        107
# земля_NOUN          89
# рука_NOUN           73
# мелкий_ADJF         53
# рыжий_ADJF          48
#                   ...
# шпана_NOUN           3
# тарабанить_INFN      3
# топ_INTJ             1
# слыхать_PRED         1
# слыхать_CONJ         1
# Name: word, Length: 221, dtype: int64
#
# Usages found per form:
# *** давиться_INFN ***
# давится     6
# давясь      2
# давиться    2
# давятся     2
# давись      1
# Name: wordat, dtype: int64
# *** давление_NOUN ***
# давления    6
# давление    2
# давлении    1
# Name: wordat, dtype: int64
# *** дека_NOUN ***
# деки    3
# дека    1
# Дека    1
# Name: wordat, dtype: int64
# *** депо_NOUN ***
# депо    10
# Name: wordat, dtype: int64
# *** дикий_ADJF ***
# дикой     7
# дикий     5
# дикие     4
# диких     4
# Дикая     2
# дикая     2
# диким     2
# дикое     2
# дикую     2
# дика      2
# дикому    1
# дики      1
# диком     1
# Дикие     1
# дикими    1
# Дикий     1
# дик       1
# дикого    1
# Name: wordat, dtype: int64
# *** дохлый_ADJF ***
# дохлый    4
# Дохлое    1
# Дохлая    1
# Name: wordat, dtype: int64
# *** драить_INFN ***
# драить    7
# драил     2
# драили    1
# Name: wordat, dtype: int64
# *** дробь_NOUN ***
# дробь     6
# дроби     6
# дробью    3
# Дробь     3
# дробях    1
# дробей    1
# Name: wordat, dtype: int64
# *** другой_ADJF ***
# другой     33
# других     19
# другом      8
# другого     7
# другие      7
# другую      6
# другими     5
# другая      5
# другое      5
# другим      4
# Другой      2
# другому     2
# Другие      1
# Другая      1
# другою      1
# Другое      1
# Name: wordat, dtype: int64
# *** жалкий_ADJF ***
# жалкий     4
# жалкое     2
# жалким     2
# жалко      2
# жалких     2
# жалкую     1
# жалок      1
# жалкая     1
# Жалок      1
# жалком     1
# жалкие     1
# жалкими    1
# Жалкая     1
# Name: wordat, dtype: int64
# *** жезл_NOUN ***
# жезл      10
# жезлом     3
# Name: wordat, dtype: int64
# *** жрать_INFN ***
# жрать    6
# жрет     2
# жрёт     1
# Жрет     1
# Name: wordat, dtype: int64
# *** забить_INFN ***
# забить       15
# забил         4
# Забить        4
# Забили        2
# Забил         2
# забившему     1
# забили        1
# Name: wordat, dtype: int64
# *** забродить_INFN ***
# забродит     2
# забродили    2
# забродил     2
# забродила    1
# забродишь    1
# Забродить    1
# Name: wordat, dtype: int64
# *** заглатывать_INFN ***
# заглатывать     2
# заглатываешь    1
# заглатывают     1
# заглатывал      1
# заглатывает     1
# заглатывали     1
# Name: wordat, dtype: int64
# *** запасть_INFN ***
# запасть    3
# западу     1
# Name: wordat, dtype: int64
# *** заправщик_NOUN ***
# заправщик     3
# заправщики    1
# Name: wordat, dtype: int64
# *** зарубить_INFN ***
# зарубил     2
# зарубить    2
# Зарубил     1
# Name: wordat, dtype: int64
# *** звонкий_ADJF ***
# звонкий     6
# звонко      4
# Звонкий     2
# звонок      2
# звонкую     2
# звонкие     1
# звонкими    1
# звонка      1
# Звонко      1
# Name: wordat, dtype: int64
# *** звучать_INFN ***
# звучит     4
# звучало    3
# звучать    2
# Звучали    1
# Звучит     1
# звучала    1
# Name: wordat, dtype: int64
# *** зелёный_ADJF ***
# зелёных    4
# зелено     2
# зелёной    2
# зелен      2
# зелёные    2
# зелёным    1
# Зелёное    1
# Зелёная    1
# Зелен      1
# Зелёный    1
# зеленых    1
# зеленые    1
# зеленый    1
# зелены     1
# Зелёной    1
# зелёном    1
# Зелёные    1
# Name: wordat, dtype: int64
# *** земля_NOUN ***
# землю     24
# земли     23
# земле     12
# земля     10
# землёй     6
# Земля      4
# Земли      2
# землею     2
# землёю     1
# Земель     1
# землях     1
# землей     1
# Землю      1
# Земле      1
# Name: wordat, dtype: int64
# *** знак_NOUN ***
# знак       6
# знаков     4
# знаком     2
# Знак       2
# знаки      1
# знака      1
# знаками    1
# Name: wordat, dtype: int64
# *** иконостас_NOUN ***
# иконостас      4
# иконостаса     1
# иконостасом    1
# Name: wordat, dtype: int64
# *** кабак_NOUN ***
# кабак      18
# кабаке      5
# кабаком     2
# Кабак       2
# кабака      2
# Кабаком     1
# кабаках     1
# кабаку      1
# Name: wordat, dtype: int64
# *** кадра_ ***
# кадрой    7
# кадры     2
# Кадры     1
# Кадра     1
# Name: wordat, dtype: int64
# *** казённый_ADJF ***
# казённый     4
# казенной     1
# казённой     1
# казённая     1
# казённым     1
# казённого    1
# Казённый     1
# Казённая     1
# Казенного    1
# Казенное     1
# казенную     1
# казенного    1
# Казенная     1
# Name: wordat, dtype: int64
# *** калина_NOUN ***
# калина    6
# Калина    3
# калину    1
# калины    1
# Калине    1
# Name: wordat, dtype: int64
# *** камера_NOUN ***
# камеры      5
# камер       4
# камера      3
# Камера      3
# камере      3
# камерах     2
# камеру      2
# камерами    1
# Name: wordat, dtype: int64
# *** каре_NOUN ***
# каре    10
# Name: wordat, dtype: int64
# *** кат_NOUN ***
# кат     4
# Кат     4
# кату    3
# ката    2
# Name: wordat, dtype: int64
# *** катран_NOUN ***
# катран     7
# Катраны    2
# Катран     1
# катрана    1
# катрану    1
# Name: wordat, dtype: int64
# *** киса_NOUN ***
# киса    6
# кису    1
# Киса    1
# Name: wordat, dtype: int64
# *** классный_ADJF ***
# классный     3
# Классное     2
# классной     2
# классно      1
# классная     1
# классных     1
# классную     1
# классного    1
# классные     1
# Name: wordat, dtype: int64
# *** колосник_NOUN ***
# колосников    3
# колосники     2
# колосником    2
# Name: wordat, dtype: int64
# *** ком_NOUN ***
# кому       6
# ком        5
# комом      3
# комья      2
# Ком        2
# Кому       1
# комьями    1
# Name: wordat, dtype: int64
# *** комковатый_ADJF ***
# комковатой     2
# комковатые     2
# комковатыми    1
# Комковатая     1
# комковатое     1
# комковатую     1
# комковато      1
# Name: wordat, dtype: int64
# *** коммерция_NOUN ***
# коммерция     2
# коммерции     2
# Коммерция     1
# коммерцией    1
# Name: wordat, dtype: int64
# *** коммерческий_ADJF ***
# коммерческих    3
# коммерческие    2
# коммерческий    1
# Коммерческий    1
# Name: wordat, dtype: int64
# *** компас_NOUN ***
# компасом    2
# Компаса     1
# компас      1
# Name: wordat, dtype: int64
# *** кончать_INFN ***
# кончать     8
# кончаешь    1
# Кончай      1
# кончай      1
# Name: wordat, dtype: int64
# *** копёр_NOUN ***
# копёр    4
# копер    1
# Копер    1
# копра    1
# Name: wordat, dtype: int64
# *** короб_NOUN ***
# короб       10
# коробов      4
# короба       3
# коробу       2
# коробами     1
# коробом      1
# Name: wordat, dtype: int64
# *** королёк_NOUN ***
# королёк      11
# королек       2
# корольки      2
# Корольком     1
# Королёк       1
# Name: wordat, dtype: int64
# *** косарь_NOUN ***
# косарь     3
# косаря     3
# косарей    1
# косарях    1
# косарям    1
# Name: wordat, dtype: int64
# *** кремль_NOUN ***
# Кремль    4
# кремли    1
# Name: wordat, dtype: int64
# *** кровля_NOUN ***
# кровли     5
# кровлю     4
# Кровля     2
# кровлей    1
# Name: wordat, dtype: int64
# *** кругом_ADVB ***
# кругом    20
# Name: wordat, dtype: int64
# *** кругом_PREP ***
# кругом    20
# Name: wordat, dtype: int64
# *** крутить_INFN ***
# крутит       5
# крутить      2
# крутили      2
# крути        2
# крутило      1
# Крутит       1
# крутившие    1
# Крути        1
# Name: wordat, dtype: int64
# *** кстати_ADVB ***
# кстати    10
# Кстати     7
# Name: wordat, dtype: int64
# *** кстати_CONJ ***
# кстати    10
# Кстати     7
# Name: wordat, dtype: int64
# *** кукурузник_NOUN ***
# кукурузник     11
# кукурузнику     2
# Кукурузник      2
# кукурузники     1
# Name: wordat, dtype: int64
# *** кургузый_ADJF ***
# кургузый    3
# кургузые    2
# Кургузая    1
# Кургузый    1
# кургузое    1
# Кургузые    1
# Name: wordat, dtype: int64
# *** курево_NOUN ***
# куревом    3
# куреве     2
# курево     1
# Name: wordat, dtype: int64
# *** лабиринт_NOUN ***
# лабиринт     5
# лабиринта    3
# лабиринте    2
# Name: wordat, dtype: int64
# *** лагерный_ADJF ***
# Лагерное    2
# лагерной    2
# лагерное    2
# лагерный    1
# лагерным    1
# лагерная    1
# Name: wordat, dtype: int64
# *** лад_NOUN ***
# лад      11
# лады      3
# ладов     2
# ладу      1
# лада      1
# ладом     1
# Name: wordat, dtype: int64
# *** ладно_ADVB ***
# ладно    5
# Ладно    5
# Name: wordat, dtype: int64
# *** ладно_PRCL ***
# ладно    5
# Ладно    5
# Name: wordat, dtype: int64
# *** ласкать_INFN ***
# ласкают    2
# ласкает    2
# ласкали    2
# ласкаю     1
# Ласкаю     1
# ласкала    1
# ласкало    1
# ласкать    1
# Name: wordat, dtype: int64
# *** латка_NOUN ***
# латку      3
# латке      3
# латка      2
# латках     1
# Латка      1
# латками    1
# латкой     1
# латки      1
# Name: wordat, dtype: int64
# *** лев_NOUN ***
# Лев      6
# лев      3
# левом    2
# львом    1
# Львом    1
# Name: wordat, dtype: int64
# *** магия_NOUN ***
# магия    4
# магию    1
# Магия    1
# магии    1
# Name: wordat, dtype: int64
# *** мамуля_NOUN ***
# мамуля    3
# Мамуля    1
# мамулю    1
# Мамуль    1
# Name: wordat, dtype: int64
# *** мара_NOUN ***
# Мара     5
# Мары     3
# мара     1
# Марой    1
# Мару     1
# Name: wordat, dtype: int64
# *** масляный_ADJF ***
# масляным     3
# Масляные     3
# масляного    3
# масляной     3
# масляные     2
# Масляный     2
# масляных     2
# масляная     2
# масляными    1
# масляную     1
# Name: wordat, dtype: int64
# *** мастер_NOUN ***
# мастер       19
# мастера       7
# Мастер        4
# мастеру       2
# мастерами     1
# мастеров      1
# Name: wordat, dtype: int64
# *** матроска_NOUN ***
# матроске     2
# Матроска     1
# матросках    1
# матроска     1
# Матроске     1
# Name: wordat, dtype: int64
# *** маячить_INFN ***
# маячить    4
# маячили    2
# маячит     2
# маячишь    1
# маячил     1
# маячила    1
# Маячить    1
# Name: wordat, dtype: int64
# *** мебельный_ADJF ***
# мебельный     3
# мебельного    2
# Мебельный     1
# мебельное     1
# мебельная     1
# мебельной     1
# мебельным     1
# Name: wordat, dtype: int64
# *** медвяный_ADJF ***
# медвяный    4
# медвяные    4
# медвяною    2
# медвяно     1
# медвяных    1
# медвяной    1
# медвяным    1
# медвяна     1
# Name: wordat, dtype: int64
# *** мелкий_ADJF ***
# мелкие     8
# мелкая     6
# мелких     5
# мелкий     5
# мелким     4
# мелко      3
# мелкой     3
# Мелкие     3
# мелкую     2
# Мелкий     2
# мелкое     2
# Мелкая     2
# мелкими    2
# Мелкому    1
# Мелкою     1
# мелкого    1
# мелкому    1
# мелки      1
# Мелко      1
# Name: wordat, dtype: int64
# *** мелькать_INFN ***
# мелькал     9
# мелькает    3
# мелькают    1
# Name: wordat, dtype: int64
# *** месть_NOUN ***
# месть     7
# мести     4
# местей    1
# Name: wordat, dtype: int64
# *** меч_NOUN ***
# меч      13
# мечом     2
# меча      1
# Name: wordat, dtype: int64
# *** мина_NOUN ***
# мина    5
# мин     2
# мины    2
# Мину    1
# мину    1
# Name: wordat, dtype: int64
# *** мирный_ADJF ***
# Мирный     7
# мирная     2
# Мирном     2
# Мирного    1
# Name: wordat, dtype: int64
# *** мирный_NOUN ***
# Мирный     7
# Мирном     2
# Мирного    1
# Name: wordat, dtype: int64
# *** мотня_NOUN ***
# мотня     4
# мотню     2
# мотнёю    1
# мотне     1
# Name: wordat, dtype: int64
# *** мёд_NOUN ***
# мёд      4
# мед      4
# медом    2
# мёдом    1
# Мед      1
# меду     1
# меда     1
# Name: wordat, dtype: int64
# *** мёрзлый_ADJF ***
# мёрзлую     3
# мёрзлой     3
# мёрзлый     3
# Мерзлая     1
# мерзла      1
# Мерзлой     1
# мёрзлые     1
# Мёрзлый     1
# мёрзлому    1
# мёрзлом     1
# Мёрзлую     1
# Name: wordat, dtype: int64
# *** рудник_NOUN ***
# рудник       2
# Рудник       1
# руднике      1
# рудниками    1
# рудники      1
# Name: wordat, dtype: int64
# *** рука_NOUN ***
# руки      24
# руках     10
# руке       9
# руку       8
# рукой      6
# руками     6
# рука       4
# рук        2
# рукам      2
# рукою      1
# Рука       1
# Name: wordat, dtype: int64
# *** рулить_INFN ***
# рулил     5
# рулит     3
# руля      1
# рулить    1
# Name: wordat, dtype: int64
# *** рыжий_ADJF ***
# рыжий     15
# Рыжий      9
# рыжими     5
# рыжая      4
# рыжего     2
# Рыжего     2
# рыжим      2
# рыж        2
# рыжее      1
# Рыжих      1
# рыжей      1
# Рыжие      1
# рыжие      1
# рыжем      1
# рыжему     1
# Name: wordat, dtype: int64
# *** рыжий_NOUN ***
# рыжий     15
# Рыжий      9
# рыжими     5
# рыжего     2
# Рыжего     2
# рыжим      2
# Рыжих      1
# Рыжие      1
# рыжие      1
# рыжем      1
# рыжему     1
# Name: wordat, dtype: int64
# *** сажалка_NOUN ***
# сажалки    3
# сажалка    2
# сажалку    1
# Name: wordat, dtype: int64
# *** салютовать_INFN ***
# салютовали    2
# салютовал     1
# салютовать    1
# салютовала    1
# Name: wordat, dtype: int64
# *** сан_NOUN ***
# сану    4
# сан     4
# Сан     3
# сана    1
# Name: wordat, dtype: int64
# *** сварочный_ADJF ***
# сварочной     3
# сварочные     2
# сварочного    2
# сварочных     2
# сварочному    1
# Сварочная     1
# Name: wordat, dtype: int64
# *** сведение_NOUN ***
# сведение     6
# Сведение     3
# сведения     2
# сведением    1
# Сведенье     1
# Name: wordat, dtype: int64
# *** сверлить_INFN ***
# сверлить    5
# сверлило    2
# сверлят     1
# Name: wordat, dtype: int64
# *** семёрка_NOUN ***
# семёрка     4
# семёрку     3
# семёрки     2
# Семёрка     2
# семерки     1
# семеркой    1
# семёркой    1
# семёрке     1
# Name: wordat, dtype: int64
# *** сердечный_ADJF ***
# сердечных     3
# сердечный     3
# Сердечный     3
# сердечную     2
# сердечная     2
# сердечного    2
# Сердечные     1
# Сердечное     1
# Сердечно      1
# сердечному    1
# Сердечных     1
# сердечные     1
# сердечной     1
# Name: wordat, dtype: int64
# *** серебристый_ADJF ***
# серебристый     2
# Серебристый     1
# серебристым     1
# серебристыми    1
# серебристой     1
# Name: wordat, dtype: int64
# *** серебрить_INFN ***
# серебрила    2
# серебрят     2
# серебрили    2
# серебрил     1
# Name: wordat, dtype: int64
# *** сеть_NOUN ***
# сеть     4
# сетью    2
# сетях    2
# сети     2
# Сети     1
# сетей    1
# Name: wordat, dtype: int64
# *** сидячий_ADJF ***
# сидячую     2
# сидячей     2
# сидячем     1
# сидячему    1
# сидячий     1
# сидячие     1
# сидячая     1
# сидячих     1
# Сидячая     1
# Сидячие     1
# Name: wordat, dtype: int64
# *** символ_NOUN ***
# символ      7
# символов    3
# символа     2
# символом    2
# Символ      1
# символах    1
# Name: wordat, dtype: int64
# *** синдикат_NOUN ***
# синдикат      3
# синдиката     2
# синдикатов    1
# Name: wordat, dtype: int64
# *** сиять_INFN ***
# сияла    5
# сияло    5
# сияет    5
# сияли    2
# сиял     2
# сияют    2
# Name: wordat, dtype: int64
# *** скатка_NOUN ***
# скатка     2
# скатки     2
# Скатка     1
# скатках    1
# скаткой    1
# скатке     1
# скатку     1
# Name: wordat, dtype: int64
# *** скорлупа_NOUN ***
# скорлупа     6
# скорлупы     2
# скорлупе     2
# Скорлупы     1
# скорлупу     1
# скорлупою    1
# Скорлупа     1
# Name: wordat, dtype: int64
# *** скорость_NOUN ***
# скорости     7
# скорость     5
# скоростью    4
# Скорость     3
# Name: wordat, dtype: int64
# *** славный_ADJF ***
# славный     6
# славные     3
# славное     3
# славною     2
# Славное     2
# славными    2
# славно      2
# славная     1
# славных     1
# славную     1
# славна      1
# Славная     1
# славного    1
# Name: wordat, dtype: int64
# *** слеза_NOUN ***
# слезы      4
# слёзы      4
# Слеза      4
# слеза      3
# слёз       2
# слез       2
# слезах     1
# слезами    1
# Name: wordat, dtype: int64
# *** слыхать_CONJ ***
# слыхать    1
# Name: wordat, dtype: int64
# *** слыхать_INFN ***
# слыхала    4
# слыхал     2
# слыхать    1
# Слыхал     1
# Name: wordat, dtype: int64
# *** слыхать_PRED ***
# слыхать    1
# Name: wordat, dtype: int64
# *** совокупность_NOUN ***
# совокупность     4
# совокупности     2
# совокупностей    1
# Name: wordat, dtype: int64
# *** сойка_NOUN ***
# сойки    3
# сойка    2
# Name: wordat, dtype: int64
# *** солнышко_NOUN ***
# солнышко    7
# Name: wordat, dtype: int64
# *** сопливый_ADJF ***
# сопливый     2
# сопливым     1
# сопливого    1
# сопливая     1
# сопливы      1
# Name: wordat, dtype: int64
# *** сочный_ADJF ***
# сочные    2
# сочное    2
# Сочное    1
# сочно     1
# Сочные    1
# сочную    1
# Name: wordat, dtype: int64
# *** сошник_NOUN ***
# сошником     2
# сошники      1
# сошника      1
# сошниками    1
# сошник       1
# Name: wordat, dtype: int64
# *** спектр_NOUN ***
# спектр     5
# спектра    1
# Name: wordat, dtype: int64
# *** спора_NOUN ***
# споры      4
# спора      3
# спорами    2
# Споры      1
# спор       1
# спорой     1
# Name: wordat, dtype: int64
# *** спорый_ADJF ***
# спорый    6
# споры     4
# споро     4
# спора     3
# спорее    2
# спорая    2
# Споры     1
# спор      1
# Спорый    1
# спорой    1
# Name: wordat, dtype: int64
# *** средство_NOUN ***
# средства      8
# средств       6
# средство      5
# средствами    4
# средством     1
# Средства      1
# средствах     1
# Name: wordat, dtype: int64
# *** срыв_NOUN ***
# срыва     8
# срыв      3
# срывы     2
# срыве     1
# срывом    1
# Name: wordat, dtype: int64
# *** стол_NOUN ***
# стол      16
# стола     14
# столе     11
# столы      3
# столу      2
# столом     1
# столов     1
# Name: wordat, dtype: int64
# *** струя_NOUN ***
# струи      6
# Струя      6
# струя      4
# струей     3
# струе      2
# Струи      2
# Струями    2
# струях     1
# струю      1
# Name: wordat, dtype: int64
# *** судак_NOUN ***
# судаков    1
# судак      1
# судака     1
# Судаком    1
# Судак      1
# Судаке     1
# Name: wordat, dtype: int64
# *** судить_INFN ***
# судил     4
# судить    4
# судили    3
# суди      2
# судя      1
# судишь    1
# судит     1
# Суди      1
# судим     1
# Name: wordat, dtype: int64
# *** сухарь_NOUN ***
# сухари      2
# сухарями    1
# сухарей     1
# сухарь      1
# Name: wordat, dtype: int64
# *** сыворотка_NOUN ***
# сыворотку     5
# сыворотка     4
# сывороткой    2
# Сыворотка     1
# Name: wordat, dtype: int64
# *** сытый_ADJF ***
# сытый     2
# сытой     2
# сыты      2
# Сытый     1
# сытые     1
# сытых     1
# сытого    1
# сытому    1
# сыт       1
# сыта      1
# Name: wordat, dtype: int64
# *** табельный_ADJF ***
# табельный    3
# Табельное    2
# табельных    1
# табельной    1
# Name: wordat, dtype: int64
# *** таблетка_NOUN ***
# таблетка     2
# таблетки     1
# таблеткой    1
# Name: wordat, dtype: int64
# *** тарабанить_INFN ***
# тарабанить    1
# тарабанил     1
# Тарабанил     1
# Name: wordat, dtype: int64
# *** таранный_ADJF ***
# Таранная    2
# таранные    1
# таранный    1
# таранная    1
# таранной    1
# Name: wordat, dtype: int64
# *** темнота_NOUN ***
# темнота    7
# Темнота    2
# темноте    1
# Name: wordat, dtype: int64
# *** тмин_NOUN ***
# тмин    4
# Name: wordat, dtype: int64
# *** тонкий_ADJF ***
# тонкий       7
# Тонкий       3
# Тонкая       2
# тонок        2
# тонких       2
# тонкие       2
# тонкой       2
# тонкая       1
# тонки        1
# Тонко        1
# Тонкие       1
# тонком       1
# тонким       1
# тонкими      1
# тончайшую    1
# Name: wordat, dtype: int64
# *** топ_INTJ ***
# топ    1
# Name: wordat, dtype: int64
# *** топ_NOUN ***
# топа    2
# топ     1
# топе    1
# Name: wordat, dtype: int64
# *** топчан_NOUN ***
# топчаны     3
# Топчан      1
# топчана     1
# топчан      1
# топчанов    1
# Name: wordat, dtype: int64
# *** точить_INFN ***
# точить     10
# точит       5
# точат       3
# точащий     1
# точи        1
# Точить      1
# Name: wordat, dtype: int64
# *** травля_NOUN ***
# травля     3
# травлю     1
# травлей    1
# травлею    1
# Name: wordat, dtype: int64
# *** трап_NOUN ***
# трап      3
# трапа     2
# трапов    2
# трапу     1
# Трапы     1
# Name: wordat, dtype: int64
# *** трубач_NOUN ***
# трубач      6
# трубачей    3
# трубачом    1
# трубачи     1
# Трубач      1
# Name: wordat, dtype: int64
# *** трёпка_NOUN ***
# трёпки    5
# трёпку    4
# Трепка    1
# трепку    1
# Name: wordat, dtype: int64
# *** тулуп_NOUN ***
# тулуп     3
# Тулуп     3
# тулупе    2
# тулупа    1
# Name: wordat, dtype: int64
# *** тупить_INFN ***
# тупит     4
# тупить    3
# тупя      3
# тупили    1
# тупят     1
# тупите    1
# тупила    1
# тупил     1
# тупило    1
# Name: wordat, dtype: int64
# *** тяжесть_NOUN ***
# тяжесть     12
# тяжестью     7
# тяжести      6
# тяжестях     1
# Name: wordat, dtype: int64
# *** убрать_INFN ***
# Убрать     6
# убрать     5
# убрали     4
# убрала     3
# убрал      2
# Убрали     2
# Уберите    1
# убран      1
# убрав      1
# Name: wordat, dtype: int64
# *** увязать_INFN ***
# увязали       4
# увязала       2
# увязанными    1
# увязать       1
# Увязают       1
# увязает       1
# Name: wordat, dtype: int64
# *** уголок_NOUN ***
# уголок     5
# уголку     1
# уголках    1
# Name: wordat, dtype: int64
# *** ужасный_ADJF ***
# ужасный     7
# ужасно      2
# ужасного    1
# ужаснее     1
# Name: wordat, dtype: int64
# *** узловатый_ADJF ***
# узловата      2
# узловатые     2
# Узловат       1
# узловатая     1
# узловатыми    1
# Name: wordat, dtype: int64
# *** условие_NOUN ***
# условия     6
# условиях    4
# условий     3
# условие     2
# условием    1
# условиям    1
# Name: wordat, dtype: int64
# *** установка_NOUN ***
# установки     5
# установка     3
# установкою    2
# Установка     2
# установке     1
# установкой    1
# установках    1
# установку     1
# Name: wordat, dtype: int64
# *** ушастый_ADJF ***
# ушастый    12
# ушастые    10
# Name: wordat, dtype: int64
# *** фартук_NOUN ***
# фартук       6
# фартуком     1
# фартуками    1
# Name: wordat, dtype: int64
# *** ферма_NOUN ***
# фермы      4
# ферма      3
# фермами    1
# Ферма      1
# Name: wordat, dtype: int64
# *** фигура_NOUN ***
# фигуры      11
# фигура       6
# фигуру       5
# Фигура       4
# фигурами     2
# фигур        2
# фигурах      1
# фигурам      1
# фигурой      1
# фигурою      1
# Name: wordat, dtype: int64
# *** фирма_NOUN ***
# фирма     8
# фирмою    3
# фирмой    3
# фирм      2
# фирму     1
# фирмы     1
# Name: wordat, dtype: int64
# *** флюс_NOUN ***
# флюс       5
# флюсы      2
# флюсах     1
# флюса      1
# флюсом     1
# Флюсами    1
# Флюсы      1
# Флюс       1
# Name: wordat, dtype: int64
# *** фон_NOUN ***
# фон      7
# фоне     2
# фонов    1
# фоном    1
# Name: wordat, dtype: int64
# *** фон_PRCL ***
# фон    7
# Name: wordat, dtype: int64
# *** фонарь_NOUN ***
# фонарь     7
# фонаря     1
# фонарей    1
# Фонарь     1
# Name: wordat, dtype: int64
# *** формула_NOUN ***
# формула      3
# формулы      1
# формулу      1
# формуле      1
# формул       1
# формулами    1
# Name: wordat, dtype: int64
# *** форте_ADJF ***
# форте    4
# Форте    1
# Name: wordat, dtype: int64
# *** форточка_NOUN ***
# форточка     2
# форточки     2
# форточкам    1
# Форточка     1
# Name: wordat, dtype: int64
# *** фофан_NOUN ***
# фофаны    4
# фофан     3
# фофана    2
# Фофан     1
# Name: wordat, dtype: int64
# *** халтура_NOUN ***
# халтура    4
# Name: wordat, dtype: int64
# *** хана_NOUN ***
# хана    2
# Хана    1
# ханы    1
# Name: wordat, dtype: int64
# *** хват_NOUN ***
# хватом    4
# хват      2
# Хват      1
# хваты     1
# Name: wordat, dtype: int64
# *** хилость_NOUN ***
# хилость     6
# хилостью    1
# Name: wordat, dtype: int64
# *** хлебало_ ***
# хлебало    4
# Хлебало    2
# хлебала    1
# Name: wordat, dtype: int64
# *** хлопья_NOUN ***
# хлопья      8
# хлопьями    8
# Хлопья      1
# хлопьев     1
# Name: wordat, dtype: int64
# *** хлыст_NOUN ***
# хлыст       4
# хлысты      2
# хлыстом     2
# хлыстов     2
# хлыстами    1
# хлыстам     1
# хлыста      1
# Хлыст       1
# Name: wordat, dtype: int64
# *** хлюст_NOUN ***
# хлюст     5
# хлюсты    3
# хлюста    1
# Хлюст     1
# Name: wordat, dtype: int64
# *** холод_NOUN ***
# холод      5
# холода     5
# холодом    1
# Name: wordat, dtype: int64
# *** хор_NOUN ***
# хор     9
# Хор     7
# хоре    2
# Хора    1
# хору    1
# Name: wordat, dtype: int64
# *** центр_NOUN ***
# центр       10
# центра       6
# центре       5
# Центр        4
# центру       3
# центров      2
# центром      2
# центры       1
# центрами     1
# Центра       1
# Name: wordat, dtype: int64
# *** цикл_NOUN ***
# циклы    3
# цикле    1
# циклу    1
# Name: wordat, dtype: int64
# *** цыкать_INFN ***
# цыкать    1
# цыкай     1
# цыкал     1
# цыкают    1
# цыкает    1
# цыкали    1
# Name: wordat, dtype: int64
# *** чад_NOUN ***
# чад      5
# Чад      2
# чада     1
# чаду     1
# чады     1
# Чадом    1
# Чада     1
# Чаде     1
# Name: wordat, dtype: int64
# *** чайник_NOUN ***
# чайник       4
# чайники      1
# Чайник       1
# чайника      1
# Чайниками    1
# Name: wordat, dtype: int64
# *** чека_NOUN ***
# чеку      3
# Чека      3
# Чекой     1
# чекой     1
# чеками    1
# чек       1
# Name: wordat, dtype: int64
# *** черныш_NOUN ***
# черныш      3
# чернышей    3
# черныши     2
# Черныш      1
# чернышом    1
# Name: wordat, dtype: int64
# *** чертовщина_NOUN ***
# чертовщина     4
# чертовщину     3
# чертовщиной    1
# Name: wordat, dtype: int64
# *** чертёж_NOUN ***
# чертёж      2
# чертежом    1
# Чертеж      1
# чертежи     1
# чертежа     1
# чертежах    1
# Name: wordat, dtype: int64
# *** четвертак_NOUN ***
# четвертак    6
# Четвертак    2
# Name: wordat, dtype: int64
# *** чирикать_INFN ***
# чирикала     2
# чирикай      2
# чирикают     1
# чирикали     1
# чирикайте    1
# Name: wordat, dtype: int64
# *** чистилище_NOUN ***
# чистилища    3
# Чистилище    2
# чистилище    1
# Name: wordat, dtype: int64
# *** чоканье_NOUN ***
# чоканье     4
# чоканья     3
# чоканьем    1
# Name: wordat, dtype: int64
# *** чувственный_ADJF ***
# чувственные     3
# чувственный     2
# чувственного    2
# чувственному    2
# чувственное     1
# Чувственное     1
# чувственен      1
# Чувственные     1
# Чувственная     1
# чувственна      1
# чувственном     1
# чувственной     1
# чувственных     1
# Name: wordat, dtype: int64
# *** чурек_NOUN ***
# чурек       2
# чуреки      1
# Чурек       1
# чуреками    1
# Чуреки      1
# чурека      1
# Name: wordat, dtype: int64
# *** шабаш_INTJ ***
# шабаш    9
# Шабаш    3
# Name: wordat, dtype: int64
# *** шабаш_NOUN ***
# шабаш      9
# Шабаш      3
# шабашах    1
# шабашем    1
# Name: wordat, dtype: int64
# *** шаманить_INFN ***
# шаманить    1
# шаманем     1
# шаманила    1
# шаманил     1
# Name: wordat, dtype: int64
# *** шестёрка_NOUN ***
# шестёрка    10
# шестёрке     2
# шестёрки     2
# шестерку     1
# Шестёрка     1
# Name: wordat, dtype: int64
# *** ширять_INFN ***
# ширяет    4
# ширял     2
# ширяй     2
# ширяло    1
# ширять    1
# Ширяй     1
# ширяют    1
# Name: wordat, dtype: int64
# *** шитьё_NOUN ***
# шитьё     3
# шитья     2
# шитьем    1
# шитьём    1
# Name: wordat, dtype: int64
# *** шифр_NOUN ***
# шифром     5
# шифр       4
# шифрами    2
# шифры      2
# шифра      2
# Шифр       1
# Name: wordat, dtype: int64
# *** шкода_NOUN ***
# Шкода    6
# шкоды    4
# шкоду    1
# Name: wordat, dtype: int64
# *** шлем_NOUN ***
# шлем    6
# Name: wordat, dtype: int64
# *** шлифовальный_ADJF ***
# шлифовальные    3
# шлифовальный    3
# шлифовальной    1
# Шлифовальные    1
# Name: wordat, dtype: int64
# *** шмара_NOUN ***
# шмара    3
# шмару    1
# Name: wordat, dtype: int64
# *** шнур_NOUN ***
# шнурами    5
# шнур       5
# шнуром     1
# шнуры      1
# шнуре      1
# Name: wordat, dtype: int64
# *** шпана_NOUN ***
# шпану    2
# шпаны    1
# Name: wordat, dtype: int64
# *** шпилить_INFN ***
# шпилить    3
# шпилил     1
# Name: wordat, dtype: int64
# *** щуп_NOUN ***
# щуп    8
# Щуп    1
# Name: wordat, dtype: int64
# *** экспресс_NOUN ***
# экспрессе     2
# экспресс      2
# экспрессом    1
# Name: wordat, dtype: int64
# *** элемент_NOUN ***
# элемент       9
# элементов     3
# элементы      2
# элементами    2
# Name: wordat, dtype: int64
# *** эпистолярный_ADJF ***
# эпистолярного    2
# Эпистолярная     1
# эпистолярный     1
# Name: wordat, dtype: int64
# *** ювелир_NOUN ***
# ювелир     4
# Ювелиры    1
# ювелира    1
# Name: wordat, dtype: int64
# *** юдоль_NOUN ***
# юдоль     6
# юдоли     6
# юдолью    2
# Юдолью    1
# Юдоль     1
# Name: wordat, dtype: int64
# *** южный_ADJF ***
# южной     5
# южному    2
# южного    2
# Южный     1
# южном     1
# Южная     1
# Южные     1
# южный     1
# Южным     1
# южные     1
# Name: wordat, dtype: int64
# *** юр_NOUN ***
# юру     10
# юр       2
# юра      1
# юром     1
# Юр       1
# Name: wordat, dtype: int64
# *** яблоко_NOUN ***
# яблоки     6
# яблоко     5
# яблоком    3
# яблока     3
# яблок      1
# Яблоко     1
# Name: wordat, dtype: int64
# *** явка_NOUN ***
# явка    7
# явки    3
# Явка    2
# явке    1
# Явки    1
# Name: wordat, dtype: int64
# *** ягодица_NOUN ***
# ягодицы     4
# Ягодица     1
# ягодице     1
# ягодицам    1
# Name: wordat, dtype: int64
# *** ядрышко_NOUN ***
# ядрышко    3
# ядрышки    1
# Name: wordat, dtype: int64
# *** язва_NOUN ***
# язва      4
# язвы      3
# Язва      2
# язвами    1
# язвою     1
# язву      1
# язв       1
# Name: wordat, dtype: int64
# *** язык_NOUN ***
# язык      13
# Язык       8
# языком     8
# языка      6
# языке      5
# языки      4
# Языком     1
# языку      1
# Name: wordat, dtype: int64
# *** ярлык_NOUN ***
# ярлык     4
# Ярлык     2
# ярлыке    1
# ярлыки    1
# Name: wordat, dtype: int64
# *** ясный_ADJF ***
# ясно      6
# ясным     6
# ясный     4
# ясные     4
# ясная     2
# Ясные     2
# ясное     2
# ясны      1
# Ясное     1
# ясна      1
# ясной     1
# ясными    1
# ясных     1
# ясного    1
# ясном     1
# Name: wordat, dtype: int64
# Dumping retrieved usages to  usages

# %% [markdown]
# # Load indices found

# %%
dfi = pd.concat([pd.read_csv(p, sep='\t') for p in Path('usages').glob('*.tsv')], ignore_index=True)
dfi.head()
# Out:
#          word       context_id  \
# 0  округ_NOUN   corpus_3329_17
# 1  округ_NOUN   corpus_560_174
# 2  округ_NOUN   corpus_557_107
# 3  округ_NOUN    corpus_558_94
# 4  округ_NOUN  corpus_5282_128
#
#                                              context positions  gold_sense_id  \
# 0  Ветер шатался по округе много дней и ночей, вы...     17-23             -1
# 1  В соответствии с принятой классификацией внутр...   174-180             -1
# 2  Дикий-барин (так его прозвали; настоящее же ег...   107-113             -1
# 3  Но всё же заявление она Ризину не передала, а ...    94-100             -1
# 4  Если Сахалин, ― как в шутку называют его местн...   128-133             -1
#
#    predict_sense_id  wordat
# 0               NaN  округе
# 1               NaN  округа
# 2               NaN  округе
# 3               NaN  округа
# 4               NaN   округ

# %%
dfi.word = dfi.word.str.split('_').str[0]

dfi = dfi.groupby(['word','context']).positions.agg(set).reset_index()
dfi.head()
# Out:
#        word                                            context  positions
# 0  аванпост  К пятому веку он [ Херсонес ] снова самое силь...  {202-210}
# 1  аванпост  Проводник бежал, Суворов заблудился, проплутал...  {126-135}
# 2  аванпост  Пулемет Родиона Малиновского был установлен на...    {47-56}
# 3  аванпост  Только в ГДР, на этом социалистическом аванпос...    {39-48}
# 4    агония  Началась мучительная агония немецких войск, за...    {21-27}

# %%
ll = dfi.positions.apply(len)
ll.value_counts()
# Out:
# 1     12964
# 2       839
# 3       246
# 4       137
# 5        57
# 6        42
# 8        21
# 7        17
# 9        17
# 10       11
# 11        8
# 12        7
# 13        5
# 15        5
# 18        4
# 16        4
# 20        2
# 19        2
# 14        2
# 23        2
# 32        1
# 31        1
# 63        1
# 42        1
# Name: positions, dtype: int64

# %% [markdown]
# ### If several occurrences found in the same example, select one of them wisely (with enough left and right context)

# %%
pd.set_option('colwidth',300)
dfi[ll==3]
# Out:
#               word  \
# 252    безвременье
# 271       беззубый
# 276     безоружный
# 341            бич
# 396          блюдо
# ...            ...
# 13972        штука
# 14028     щекотать
# 14165           юр
# 14299         язык
# 14308       яичный
#
#                                                                                                                                                                                                                                                                                         context  \
# 252                                                                                                                                                                 Время красит, безвременье старит. Было время, осталось одно безвременье. Безвременье придет -- все добро как мылом возьмет.
# 271                                                                                                                                                                                                                       Черепаха беззубое животное. Беззубая старуха. Беззубая борона, вилка,
# 276                                                                                                                                                   С безоружными жителями не воюют. Заяц безоружное животное. Безоружным глазом не увидишь ни спутников планетных, ни мельчайших наливняков.
# 341    Прикочевавшие к теплу советские бичи прочно заняли в сознании и обществе чеченцев место лайев, пришлых батраков. 〈…〉 Когда бичи жили при хозяевах, то милиция их не трогала — каждый селянин был милиционеру друг или родственник. 〈…〉 Колька был особенный бич. Прежде всего он не пил.
# 396                                                                                                                                          За столом было двенадцать блюд или перемен. До французских блюд я не охотник. За спесивым кумом не находишься с блюдом, потчуя. Тот же блин, да на
# ...                                                                                                                                                                                                                                                                                         ...
# 13972                                                                                                                                                                                Штука обеденный, банкетный стол, складной, раскидной ипр. Штука с полами и штука раздвижная на 24 прибора.
# 14028                                                           юж., щелоктать раждать особое чувство раздраженья в теле, в коже, касаясь её или перебирая пальцами. Детей никогда не щекочи, это шутка вредная. Шипучка инно в ногу щекочет, защекотала. Зуд щекочет. Щекотни-ка его под бока!
# 14165                                                                                                                                                                                                            На мельнице юр-юром, завозно, много народу. Лавка на юру, на самом углу рынка.
# 14299                                              Язык колокола, [или в колоколе, то, что в нем звучит, действует], било, клепало, железный пест, кистень, привешиваемый внутри под шелом колокола, для звону. Ямщики любят подвязывать в колокольчик кольцо вместо языка. Без языка и колокол
# 14308                                                                                                                                                                               желток, -- белок. Яичное-заговенье перед Петровками. Яичное-дерево, Solanum ovigerum, род поклажан. Яичный-
#
#                          positions
# 252          {14-25, 60-71, 73-84}
# 271           {46-54, 28-36, 9-17}
# 276           {2-13, 59-69, 38-48}
# 341      {32-36, 123-127, 252-255}
# 396        {26-30, 59-63, 112-118}
# ...                            ...
# 13972          {75-80, 58-63, 0-5}
# 14028  {118-124, 165-172, 190-197}
# 14165        {15-19, 12-14, 53-56}
# 14299      {210-215, 221-226, 0-4}
# 14308      {100-106, 18-24, 53-59}
#
# [246 rows x 3 columns]

# %%
def select_occurrence(pp, context):
    if len(pp) == 1:
        return next(iter(pp))

    pps = sorted([list(map(int, p.split('-'))) for p in  pp], key=lambda p: p[0])
    if len(pps) == 2:
        # when two occurrences, select the one which has longer context both to the right and to the left; 
        # short left or right context (especially when one of them is empty) may be a problem for some Transformer heads
        left = pps[0][0] 
        right = len(context) - pps[1][1]
        return '-'.join( map(str, pps[0] if left > right else pps[1]) )
        
    # the heuristic takes second to last occurrence, it has the longest left context
    # and also some right context
    return '-'.join(map(str,pps[-2]))

# %%
dfi['positions'] = dfi.apply(lambda r: select_occurrence(r.positions, r.context), axis=1)

# %%
dfi[ll==2]
# Out:
#                word  \
# 44     ангажировать
# 64        антихрист
# 70       аристократ
# 87          артерия
# 99            аршин
# ...             ...
# 14221          явка
# 14272          язык
# 14379         ясный
# 14386        ястреб
# 14394        ячмень
#
#                                                                                                                                                                                                                                                                                                            context  \
# 44                                                                                                                                                Тебя местные органы, небось, уже на полную катушку ангажировали, а? — Славка протянула «офицеру» свой пустой стакан. — Они его ангажировали от слова «выжимать».
# 64                                                                     Раскол был уходом из истории, потому что историей овладел князь этого мира, антихрист, проникший на вершины церкви и государства. 〈…〉 Уход из государства оправдывался тем, что в нём не было правды, торжествовал не Христос, а антихрист.
# 70                                                                                                                                                                                           Ему хочется попасть в аристократы, он лезет в знать. Во всяком сословии и звании могуть быть своего рода аристократы,
# 87     артерии несут алую кровь из сердца по всем частям тела, откуда она, через тончайшие волосные сосуды, возвращается венами это большой кровеоборот, питания; артерии же, или боевые жилы, проводят обращенную в сердце чорную кровь в легкия, откуда она возвращается в сердце венами; это малый кровеобор...
# 99                                                                                                                                                                                                             Водку пили не рюмками, а «аршинами», и нужно было выпить не менее аршина рюмок, поставленных в ряд.
# ...                                                                                                                                                                                                                                                                                                            ...
# 14221                                                                                                                                                                                                Плейшнер пошёл к дому, где помещалась явка, и, взглянув в окно, увидел высокого хозяина явки и черноволосого.
# 14272                                                                                                                                                                И вот, вы и не успеете заметить, как язык хамелеона, молниеносным движением выброшенный вперёд, уже возвращается с прилипшей к языку добычей.
# 14379                                          Ясные с тёмной поволокой глаза молодой вдовы были очень мало заплаканы, и чуть только она со свёкром выехала с кладбища на поле, отделяющее могилки от города, эти ясные глаза совсем высохли и взглянули из-под густых ресниц своих ещё чище, чем смотрели доселе.
# 14386                                                                                                                                                                                               ястреб голубятник, тетеревятник, тетерник и кобчик, перепелятник; сарыча и балабана инде также зовут ястребом,
# 14394                                                                                                                                                                                                                                    Ячмень, ячменёк на глазу, нарывчик в хрящевой окраине века. Ее все ячмени
#
#       positions
# 44        51-63
# 64        76-85
# 70        22-33
# 87      155-162
# 99        66-72
# ...         ...
# 14221     38-42
# 14272     37-41
# 14379   163-168
# 14386   101-109
# 14394     67-73
#
# [839 rows x 3 columns]

# %% [markdown]
# ## Add positions to the main dataset

# %%
dfi = dfi.rename(columns={'context':'example'})

# %%
dfm = df.merge(dfi, on=['word','example'], how='left')
len(df), len(dfm)
# Out:
# (2126, 2126)

# %%
# old examples are glosses, which often do not target word
dfm[dfm.positions.isnull()].period.value_counts()
# Out:
# old    170
# new      1
# Name: period, dtype: int64

# %%
# old examples are glosses, which often do not target word, we don't need positions for them; look at the new ones
dfm[dfm.positions.isnull() & (dfm.period=='new')]
# Out:
#           usage_id     word      orth sense_id gloss example  \
# 1122  test_ru_1126  королёк  королёкъ      NaN   NaN       ъ
#
#       indices_target_token date period positions
# 1122                   NaN  new    new       NaN

# %% [markdown]
# # Now add wordforms manually to forms_add.csv...
# Based on the table above, we added wordforms manually to forms_add.csv and reran the notebook from the beginning.
# Those usages that do not contain the target word are errors in the original dataset.

# %%
# For our methods, we didn't need positions of the target word for the old usage. We saved time and didn't
# try to add additional wordforms for the old usages. But dumped them to fix in the future.
dfm[dfm.positions.isnull() & ~dfm.example.isnull() & (dfm.period=='old')][['usage_id','word','example']].to_csv(
    'partially_errors.tsv',sep='\t',index=False)

# %%
# This usage from the test set is an error, we didn't want to add this to our wordforms; 
# however, we cannot drop examples from the test set, so just set some indices
dfm.loc[dfm.usage_id=='test_ru_1126','indices_target_token'] = '0-1'

# %% [markdown]
# # Save the dataframe with recovered indices

# %%
dfm['indices_target_token'] = dfm.positions.str.split('-').str.join(':')
dfr = dfm.drop(columns=['positions'])
dfr.head()
# Out:
#     usage_id     word     orth             sense_id  \
# 0  test_ru_0  мёрзлый  мёрзлый  merzlyj_khrrgztit4U
# 1  test_ru_1  мёрзлый  мёрзлый                  NaN
# 2  test_ru_2  мёрзлый  мёрзлый                  NaN
# 3  test_ru_3  мёрзлый  мёрзлый                  NaN
# 4  test_ru_4  мёрзлый  мёрзлый                  NaN
#
#                                    gloss  \
# 0  разг., устар. очень холодный; ледяной
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                                                                                                                                                                                 example  \
# 0                                                                                                                 Мерзлая земля скажется, только руку приложи От того нельзя, что земля мерзла. Мерзлой
# 1                                                             Пантелей Прокофьевич сунул Григорию мёрзлую руку, сел на край лавки, запахивая полу тулупа, обходя взглядом Аксинью, пристывшую у люльки.
# 2                                                                                                   Между домом и рельсами, за широкой мёрзлой лужей, проходила дорога, по которой возили дрова и воду.
# 3                                                                                                                  — Да, холодно, должно быть. На полу мёрзлые тараканы валяются. И мыши тоже помёрзли.
# 4  Когда мосты были прорваны, безоружные солдаты, московские жители, женщины с детьми, бывшие в обозе французов, — всё под влиянием силы инерции не сдавалось, а бежало вперед в лодки, в мёрзлую воду.
#
#   indices_target_token date period
# 0                70:76  old    old
# 1                36:43  new    new
# 2                35:42  new    new
# 3                36:43  new    new
# 4              183:190  new    new

# %%
dfr.to_csv('fixedindices_'+p.name, sep='\t', index=False)

# %% [markdown]
# # Some auxiliary inspection

# %%
dfm.query('date=="old"').groupby('word').usage_id.nunique()
# Out:
# word
# давиться    1
# давление    2
# дека        2
# депо        1
# дикий       4
#            ..
# ядрышко     1
# язва        1
# язык        8
# ярлык       2
# ясный       1
# Name: usage_id, Length: 211, dtype: int64

# %%
dfm.query('word=="язык"').query('date=="old"')
# Out:
#           usage_id  word   orth           sense_id  \
# 1567  test_ru_1571  язык  языкъ  jazyk_oQqlJWJDoFM
# 1573  test_ru_1577  язык  языкъ  jazyk_H1RadLJXL04
# 1576  test_ru_1580  язык  языкъ  jazyk_Z3SGNzPN1mg
# 1579  test_ru_1583  язык  языкъ  jazyk_S0YtaHtThcY
# 1582  test_ru_1586  язык  языкъ  jazyk_yPqs_d_x5C4
# 1583  test_ru_1587  язык  языкъ  jazyk_PNFSmmmTmhk
# 1591  test_ru_1595  язык  языкъ  jazyk_RpvHYZLUoTs
# 1595  test_ru_1599  язык  языкъ  jazyk_vM2JZPy1_oU
#
#                                                                                                                                                                                                           gloss  \
# 1567                                                                                                                               продольная палочка с зарубкою, с коей срывается отвесная подставка, сторожок
# 1573                                                                                                                                                                        било, которое ходит между щеками её
# 1576                                                   перен. подвесная деталь колокола (звонка, колокольчика и т. п.), как правило, в виде металлического стержня, которая, ударяясь о стенку, производит звук
# 1579  анат. подвижный мускулистый орган в ротовой полости позвоночных животных и человека, служащий для определения вкуса, захватывания, пережёвывания и глотания пищи, а у человека также для артикуляции речи
# 1582                                                                                                                                                                      пружинка, крючок, по коему бьют играя
# 1583                                                                                                                                     арх. слово из Архангельской губернии подводная ледяная коса, от тороса
# 1591                                                                                                                         нутреная воронка мережи, вентера, через которую рыба входит детыш, детинец, ушинок
# 1595                                                                                                                                        пищик, тонкая деревянная пластинка, вставляемая в губник, для звука
#
#                                                                                                                                                                                                                                            example  \
# 1567                                                                                                                                                                                                            Язык в ловушке, насторожка, язычок
# 1573                                                                                                                                                                                                                                   Язык мялицы
# 1576  Язык колокола, [или в колоколе, то, что в нем звучит, действует], било, клепало, железный пест, кистень, привешиваемый внутри под шелом колокола, для звону. Ямщики любят подвязывать в колокольчик кольцо вместо языка. Без языка и колокол
# 1579                                                                                                                                                       Коровий язык, лизун; рыбий, тумак; змеиный, жало, вилка; песий, лопата; кошачий, терка.
# 1582                                                                                                                                                                                                                           Язык, язычок органа
# 1583                                                                                                                                                                                                                                           NaN
# 1591                                                                                                                                                                                                                                           NaN
# 1595                                                                                                                                                                                                                          Язык кларнета, гобоя
#
#       indices_target_token date period positions
# 1567                   NaN  old    old       0-4
# 1573                   NaN  old    old       0-4
# 1576                   NaN  old    old   210-215
# 1579                   NaN  old    old      8-12
# 1582                   NaN  old    old       0-4
# 1583                   NaN  old    old       NaN
# 1591                   NaN  old    old       NaN
# 1595                   NaN  old    old       0-4
